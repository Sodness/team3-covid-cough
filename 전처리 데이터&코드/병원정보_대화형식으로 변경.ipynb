# %%
import pandas as pd

# %%
df = pd.read_excel('./병원정보/선별진료소.xlsx')
df1= pd.read_excel('./병원정보/호흡기환자진료센터.xlsx')

# %%
df1
# Out:
#          시군구  읍면동           의료기관명  \
# 0     서울 강남구  삼성동  (의)미래의료재단리드림의원
# 1     서울 강남구  대치동    365열린가정의학과의원
# 2     서울 강남구  논현동    365코이이비인후과의원
# 3     서울 강남구  삼성동         가온경희한의원
# 4     서울 강남구  삼성동    강남365가정의학과의원
# ...      ...  ...             ...
# 3010  서울 중랑구  상봉동            행복의원
# 3011  서울 중랑구  신내동    현엠앤엠소아청소년과의원
# 3012  서울 중랑구  면목동         혜림소아과의원
# 3013  서울 중랑구  망우동          홍이내과의원
# 3014  서울 중랑구  망우동      홍종찬이비인후과의원
#
#                                                      주소          전화번호
# 0     서울특별시 강남구 테헤란로 513, (삼성동, B1일부,4,9,10층,테헤란로81길...   02-540-0001
# 1                서울특별시 강남구 도곡로 405, 삼환 아르누보2 204호 (대치동)   02-565-7119
# 2                  서울특별시 강남구 강남대로118길 12, 부경빌딩 5층 (논현동)  02-2540-0442
# 3                    서울특별시 강남구 선릉로 654, 예인빌딩 401호 (삼성동)  02-3443-6789
# 4              서울특별시 강남구 학동로 346, 강남구청역 지하1층 102호 (삼성동)  02-3442-7668
# ...                                                 ...           ...
# 3010                     서울특별시 중랑구 봉화산로 105, 1,2층 (상봉동)   02-496-1323
# 3011                서울특별시 중랑구 신내로 82, 403호 (신내동, 금강프라자)  02-3422-1253
# 3012                           서울특별시 중랑구 면목로 415, (면목동)   02-491-4018
# 3013                        서울특별시 중랑구 겸재로 237, 3층 (망우동)  02-6952-1209
# 3014                       서울특별시 중랑구 용마산로 502, 3층 (망우동)   02-436-2315
#
# [3015 rows x 5 columns]

# %%
df=df.dropna(axis=1)
df
# Out:
#        시군구  읍면동     의료기관명                         주소          전화번호
# 0   서울 강남구  삼성동    강남구보건소  서울 강남구 삼성동(삼성2동) 8 강남구보건소  02-3423-5555
# 1   서울 강남구  일원동    삼성서울병원        서울 강남구 일원로81 삼성서울병원  02-1599-3114
# 2   서울 강남구  도곡동  강남세브란스병원     서울 강남구 언주로211 강남세브란스병원  02-1599-6114
# 3   서울 강남구  도곡동   강남베드로병원                  남부순환로2637  02-1544-7522
# 4   서울 강동구  성내동    강동구보건소               서울 강동구 성내로45  02-3425-6713
# ..     ...  ...       ...                        ...           ...
# 59  서울 종로구   평동    강북삼성병원            서울시 종로구 새문안로 29  02-2001-1896
# 60  서울 종로구   평동   서울적십자병원             서울시 종로구 평동 164  02-2002-8000
# 61  서울 중랑구  신내동    중랑구보건소      서울 중랑구 신내2동 662 중랑구청   02-2094-0800
# 62  서울 중랑구  신내동     서울의료원                중랑구 신내로 156  02-2276-8333
# 63  서울 중랑구  면목동      녹색병원            중랑구 사가정로 49길 53   02-490-2000
#
# [64 rows x 5 columns]

# %%
df_a=df1
df_a['질문']=df_a['시군구']+" "+df_a['읍면동']
df_a['답변']="병원명은 "+df_a['의료기관명']+" 주소는 "+df_a['주소']+" 전화번호는 "+df_a['전화번호']+" 입니다."
df_a=df_a.drop(['시군구','읍면동','의료기관명','주소','전화번호'],axis=1)
df_a.to_excel('./병원정보/호흡기환자진료센터_질문답변.xlsx')

# %%
import openpyxl



# 한 건의 대화에 대한 정보를 담는 객체입니다.

class Conversation:

    

    # 질문(Question), 응답(Answer) 두 변수로 구성됩니다.

    def __init__(self, contentName, contentType, question, answer):

        self.contentName = contentName

        self.contentType = contentType

        self.question = question

        self.answer = answer



    def __str__(self):

        return "질문: " + self.question + "\n답변: " + self.answer + "\n"



# 영어 대화 데이터가 담긴 엑셀 파일을 엽니다.

wb = openpyxl.load_workbook('./병원정보/선별진료소_질문답변.xlsx')

 

# 활성 시트를 얻습니다.

ws = wb.active



conversations = []



# 시트 내에 존재하는 모든 영어 대화 데이터를 객체로 담습니다.

for r in ws.rows:

    c = Conversation(r[0].value, r[1].value, r[2].value, r[3].value)

    conversations.append(c)

    

wb.close()



for c in conversations:

    print(str(c))

    

# 모든 대화 내용을 출력합니다.

for c in conversations:

    print(str(c))

    

print('총 ', len(conversations), '개의 대화가 존재합니다.')
# Out:
# 질문: 질문
# 답변: 답변
#
# 질문: 서울 강남구 삼성동
# 답변: 병원명은 강남구보건소 주소는 서울 강남구 삼성동(삼성2동) 8 강남구보건소 전화번호는 02-3423-5555 입니다.
#
# 질문: 서울 강남구 일원동
# 답변: 병원명은 삼성서울병원 주소는 서울 강남구 일원로81 삼성서울병원 전화번호는 02-1599-3114 입니다.
#
# 질문: 서울 강남구 도곡동
# 답변: 병원명은 강남세브란스병원 주소는 서울 강남구 언주로211 강남세브란스병원 전화번호는 02-1599-6114 입니다.
#
# 질문: 서울 강남구 도곡동
# 답변: 병원명은 강남베드로병원 주소는 남부순환로2637 전화번호는 02-1544-7522 입니다.
#
# 질문: 서울 강동구 성내동
# 답변: 병원명은 강동구보건소 주소는 서울 강동구 성내로45 전화번호는 02-3425-6713 입니다.
#
# 질문: 서울 강동구 둔촌동
# 답변: 병원명은 중앙보훈병원 주소는 서울 강동구 진황도로 61길 53 전화번호는 02-2225-1114 입니다.
#
# 질문: 서울 강동구 상일동
# 답변: 병원명은 강동경희대병원 주소는 서울시 강동구 동남로 892 전화번호는 02-440-7000 입니다.
#
# 질문: 서울 강동구 길동
# 답변: 병원명은 강동성심병원 주소는 서울시 강동구 성안로 150 전화번호는 1588-4100 입니다.
#
# 질문: 서울 강북구 번동
# 답변: 병원명은 강북구보건소 주소는 서울 강북구 한천로 897, 강북구보건소 전화번호는 02-901-7704.7706 입니다.
#
# 질문: 서울 강서구 염창동
# 답변: 병원명은 강서구보건소 주소는 서울 강서구 염창동 275-12 강서보건소 전화번호는 02-2600-5465 입니다.
#
# 질문: 서울 관악구 청룡동
# 답변: 병원명은 관악구보건소 주소는 서울 관악구 청룡동 1570-1  전화번호는 02-879-7133/7136 입니다.
#
# 질문: 서울 관악구 신림동
# 답변: 병원명은 에이치플러스양지병원 주소는 서울특별시 관악구 남부순환로 1636 전화번호는 1877-8875 입니다.
#
# 질문: 서울 광진구 자양동
# 답변: 병원명은 광진구보건소 주소는 서울특별시 광진구 자양1동 777 전화번호는 02-450-7090 입니다.
#
# 질문: 서울 광진구 화양동
# 답변: 병원명은 건국대학교병원 주소는 서울특별시 광진구 능동로 120-1 전화번호는 02-1588-1533 입니다.
#
# 질문: 서울 구로구 구로동
# 답변: 병원명은 구로구보건소 주소는 서울 구로구 구로동(구로제5동) 109-4 구로5동 주민센터, 구로구보건소 전화번호는 02-860-3000 입니다.
#
# 질문: 서울 금천구 시흥동
# 답변: 병원명은 금천구보건소 주소는 서울 금천구 시흥제1동 1020 금천구보건소  전화번호는 02-2627-2717 입니다.
#
# 질문: 서울 금천구 시흥동
# 답변: 병원명은 희명병원 주소는 서울특별시 금천구 시흥대로 244 전화번호는 02-2219-7231 입니다.
#
# 질문: 서울 노원구 상계동
# 답변: 병원명은 노원구보건소 주소는 서울 노원구 상계6.7동 노원구보건소, 701-1 전화번호는 02-2116-4900 입니다.
#
# 질문: 서울 노원구 상계동
# 답변: 병원명은 상계백병원 주소는 서울 노원구 동일로 1342 전화번호는 02-950-1114 입니다.
#
# 질문: 서울 도봉구 쌍문동
# 답변: 병원명은 도봉구보건소 주소는 서울 도봉구 쌍문동 565 전화번호는 02-2091-4490 입니다.
#
# 질문: 서울 도봉구 쌍문동
# 답변: 병원명은 한일병원 주소는 서울시 도봉구 우이천로 308(쌍문동)  전화번호는 02-901-3114 입니다.
#
# 질문: 서울 동대문구 용두동
# 답변: 병원명은 동대문구보건소 주소는 서울 동대문구 용두동 39-9  전화번호는 02-2127-4283 입니다.
#
# 질문: 서울 동대문구 휘경동
# 답변: 병원명은 삼육서울병원 주소는 서울 동대문구 망우로 82 전화번호는 1577-3675 입니다.
#
# 질문: 서울 동대문구 용두동
# 답변: 병원명은 서울특별시동부병원 주소는 서울 동대문구 무학로 124  전화번호는 920-9435 입니다.
#
# 질문: 서울 동대문구 청량리동
# 답변: 병원명은 서울성심병원 주소는 서울 동대문구 왕산로 259 전화번호는 966-1616 입니다.
#
# 질문: 서울 동대문구 회기동
# 답변: 병원명은 경희의료원 주소는 서울 동대문구 경희대로 23 전화번호는 958-8114 입니다.
#
# 질문: 서울 동작구 상도동
# 답변: 병원명은 동작구보건소 주소는 서울 동작구 상도2동 176-3 전화번호는 1533-5571 입니다.
#
# 질문: 서울 동작구 보라매동
# 답변: 병원명은 서울특별시 보라매병원 주소는 동작구 보라매로5길 20 전화번호는 02-870-2114 입니다.
#
# 질문: 서울 동작구 흑석동
# 답변: 병원명은 서울특별시 중앙대학교 병원 주소는 서울특별시 동작구 흑석로 102 전화번호는 1800-1114 입니다.
#
# 질문: 서울 마포구 성산동
# 답변: 병원명은 마포구보건소 주소는 서울 마포구 성산동 370 전화번호는 1577-3160 입니다.
#
# 질문: 서울 서대문구 연희동
# 답변: 병원명은 서대문구보건소 주소는 서울 서대문구 연희동  연희로242 (연희동 165-2) 전화번호는 02-330-1806 입니다.
#
# 질문: 서울 서대문구 신촌동
# 답변: 병원명은 세브란스병원 주소는 연세로 50-1 전화번호는 1599-1004 입니다.
#
# 질문: 서울 중구 신당동
# 답변: 병원명은 서울중구보건소 주소는 서울 중구 신당동 50-5 중구보건소   전화번호는 02-3396-8119 입니다.
#
# 질문: 서울 중구 저동
# 답변: 병원명은 인제대학교서울백병원 주소는 서울 중구 마른내로 9 백병원 전화번호는 02-2270-0114 입니다.
#
# 질문: 서울 중구 을지로
# 답변: 병원명은 국립중앙의료원 주소는 중구 을지로 245 전화번호는 02-2260-7114 입니다.
#
# 질문: 서울 서초구 서초동
# 답변: 병원명은 서초구보건소 주소는 서울 서초구 서초동(서초2동) 1376-3 서초구청 보건소 전화번호는 02-2155-8093 입니다.
#
# 질문: 서울 서초구 반포동
# 답변: 병원명은 가톨릭대학교 서울성모병원 주소는 서울시 서초구 반포대로 222 전화번호는 02-1588-1511 입니다.
#
# 질문: 서울 서초구 내곡동
# 답변: 병원명은 서울특별시 어린이병원 주소는 서울특별
#
# 질문: 서울 성동구 홍익동
# 답변: 병원명은 성동구보건소 주소는 서울 성동구 홍익동 (왕십리도선동) 16-15 성동구보건소  전화번호는 02-2286-7172 입니다.
#
# 질문: 서울 성동구 사근동
# 답변: 병원명은 한양대학교병원 주소는 서울특별시 성동구 왕십리로 222-1 (사근동) 전화번호는 02-2290-8114/8531 입니다.
#
# 질문: 서울 성동구 송정동
# 답변: 병원명은 성동군자의원 주소는 서울특별시 성동구 광나루로 323 송정빌딩 2층 전화번호는 02-499-7785 입니다.
#
# 질문: 서울 성북구 하월곡동
# 답변: 병원명은 성북구보건소 주소는 서울특별시 성북구 화랑로 63(하월곡동, 성북구보건소)  전화번호는 02-2241-5912 입니다.
#
# 질문: 서울 송파구 신천동
# 답변: 병원명은 송파구보건소 주소는 서울 송파구 신천동 29-5 송파구청, 보건소  전화번호는 02-2147-3478 입니다.
#
# 질문: 서울 송파구 풍납동
# 답변: 병원명은 서울아산병원 주소는 올림픽로43길 88 전화번호는 02-1688-7575 입니다.
#
# 질문: 서울 양천구 신정동
# 답변: 병원명은 양천구보건소 주소는 서울 양천구 신정동(신정6동) 321-5 양천보건소 전화번호는 1533-0407 입니다.
#
# 질문: 서울 양천구 신정동
# 답변: 병원명은 서울특별시 서남병원 주소는 양천구 신정이펜1로 20 전화번호는 1566-6688 입니다.
#
# 질문: 서울 양천구 목동
# 답변: 병원명은 홍익병원 주소는 서울 양천구 목동로 225  전화번호는 02-2693-5555 입니다.
#
# 질문: 서울 영등포구 당산동
# 답변: 병원명은 영등포구보건소 주소는 서울 영등포구 당산동3가(당산제1동) 385-1 영등포구청 영등포구보건소 전화번호는 02-2670-4954~9 입니다.
#
# 질문: 서울 영등포구 신길동
# 답변: 병원명은 한림대학교 강남성심병원 주소는 서울특별시 영등포구 신길로 1 전화번호는 1577-5587 입니다.
#
# 질문: 서울 영등포구 신길동
# 답변: 병원명은 의료법인 성애병원 주소는 서울특별시 영등포구 여의대방로 53길22 전화번호는 02-840-7538 입니다.
#
# 질문: 서울 영등포구 대림동
# 답변: 병원명은 명지성모병원 주소는 서울특별시 영등포구도림로 156 전화번호는 02-829-7800 입니다.
#
# 질문: 서울 영등포구 당산동
# 답변: 병원명은 인봉의료재단 영등포병원 주소는 서울특별시 영등포구 당산로31길 10 전화번호는 010-5334-7708 입니다.
#
# 질문: 서울 용산구 이태원동
# 답변: 병원명은 용산구보건소 주소는 서울 용산구 이태원동 34-87 전화번호는 02-2199-8373~6 입니다.
#
# 질문: 서울 용산구 한남동
# 답변: 병원명은 순천향대학교서울병원 주소는 용산구 대사관로 59(한남동) 전화번호는 02-709-9114 입니다.
#
# 질문: 서울 은평구 녹번동
# 답변: 병원명은 은평구보건소 주소는 서울 은평구 녹번동 84 은평구종합청사 은평구보건소 전화번호는 02-351-8640~1 입니다.
#
# 질문: 서울 은평구 역촌동
# 답변: 병원명은 서울특별시서북병원 주소는 은평구 갈현로7길 49 전화번호는 02-3156-3022 입니다.
#
# 질문: 서울 은평구 응암동
# 답변: 병원명은 서울특별시은평병원 주소는 은평구 백련산로 90 전화번호는 02-300-8124 입니다.
#
# 질문: 서울 은평구 갈현동
# 답변: 병원명은 의료법인 청구성심병원 주소는 서울 은평구 통일로 873 전화번호는 350-3300 입니다.
#
# 질문: 서울 종로구 청운효자동
# 답변: 병원명은 종로구보건소 주소는 서울 종로구 옥인동(청운효자동) 45-30 종로구보건소 전화번호는 02-2148-2060 입니다.
#
# 질문: 서울 종로구 평동
# 답변: 병원명은 강북삼성병원 주소는 서울시 종로구 새문안로 29 전화번호는 02-2001-1896 입니다.
#
# 질문: 서울 종로구 평동
# 답변: 병원명은 서울적십자병원 주소는 서울시 종로구 평동 164 전화번호는 02-2002-8000 입니다.
#
# 질문: 서울 중랑구 신내동
# 답변: 병원명은 중랑구보건소 주소는 서울 중랑구 신내2동 662 중랑구청  전화번호는 02-2094-0800 입니다.
#
# 질문: 서울 중랑구 신내동
# 답변: 병원명은 서울의료원 주소는 중랑구 신내로 156 전화번호는 02-2276-8333 입니다.
#
# 질문: 서울 중랑구 면목동
# 답변: 병원명은 녹색병원 주소는 중랑구 사가정로 49길 53 전화번호는 02-490-2000 입니다.
#
# 질문: 질문
# 답변: 답변
#
# 질문: 서울 강남구 삼성동
# 답변: 병원명은 강남구보건소 주소는 서울 강남구 삼성동(삼성2동) 8 강남구보건소 전화번호는 02-3423-5555 입니다.
#
# 질문: 서울 강남구 일원동
# 답변: 병원명은 삼성서울병원 주소는 서울 강남구 일원로81 삼성서울병원 전화번호는 02-1599-3114 입니다.
#
# 질문: 서울 강남구 도곡동
# 답변: 병원명은 강남세브란스병원 주소는 서울 강남구 언주로211 강남세브란스병원 전화번호는 02-1599-6114 입니다.
#
# 질문: 서울 강남구 도곡동
# 답변: 병원명은 강남베드로병원 주소는 남부순환로2637 전화번호는 02-1544-7522 입니다.
#
# 질문: 서울 강동구 성내동
# 답변: 병원명은 강동구보건소 주소는 서울 강동구 성내로45 전화번호는 02-3425-6713 입니다.
#
# 질문: 서울 강동구 둔촌동
# 답변: 병원명은 중앙보훈병원 주소는 서울 강동구 진황도로 61길 53 전화번호는 02-2225-1114 입니다.
#
# 질문: 서울 강동구 상일동
# 답변: 병원명은 강동경희대병원 주소는 서울시 강동구 동남로 892 전화번호는 02-440-7000 입니다.
#
# 질문: 서울 강동구 길동
# 답변: 병원명은 강동성심병원 주소는 서울시 강동구 성안로 150 전화번호는 1588-4100 입니다.
#
# 질문: 서울 강북구 번동
# 답변: 병원명은 강북구보건소 주소는 서울 강북구 한천로 897, 강북구보건소 전화번호는 02-901-7704.7706 입니다.
#
# 질문: 서울 강서구 염창동
# 답변: 병원명은 강서구보건소 주소는 서울 강서구 염창동 275-12 강서보건소 전화번호는 02-2600-5465 입니다.
#
# 질문: 서울 관악구 청룡동
# 답변: 병원명은 관악구보건소 주소는 서울 관악구 청룡동 1570-1  전화번호는 02-879-7133/7136 입니다.
#
# 질문: 서울 관악구 신림동
# 답변: 병원명은 에이치플러스양지병원 주소는 서울특별시 관악구 남부순환로 1636 전화번호는 1877-8875 입니다.
#
# 질문: 서울 광진구 자양동
# 답변: 병원명은 광진구보건소 주소는 서울특별시 광진구 자양1동 777 전화번호는 02-450-7090 입니다.
#
# 질문: 서울 광진구 화양동
# 답변: 병원명은 건국대학교병원 주소는 서울특별시 광진구 능동로 120-1 전화번호는 02-1588-1533 입니다.
#
# 질문: 서울 구로구 구로동
# 답변: 병원명은 구로구보건소 주소는 서울 구로구 구로동(구로제5동) 109-4 구로5동 주민센터, 구로구보건소 전화번호는 02-860-3000 입니다.
#
# 질문: 서울 금천구 시흥동
# 답변: 병원명은 금천구보건소 주소는 서울 금천구 시흥제1동 1020 금천구보건소  전화번호는 02-2627-2717 입니다.
#
# 질문: 서울 금천구 시흥동
# 답변: 병원명은 희명병원 주소는 서울특별시 금천구 시흥대로 244 전화번호는 02-2219-7231 입니다.
#
# 질문: 서울 노원구 상계동
# 답변: 병원명은 노원구보건소 주소는 서울 노원구 상계6.7동 노원구보건소, 701-1 전화번호는 02-2116-4900 입니다.
#
# 질문: 서울 노원구 상계동
# 답변: 병원명은 상계백병원 주소는 서울 노원구 동일로 1342 전화번호는 02-950-1114 입니다.
#
# 질문: 서울 도봉구 쌍문동
# 답변: 병원명은 도봉구보건소 주소는 서울 도봉구 쌍문동 565 전화번호는 02-2091-4490 입니다.
#
# 질문: 서울 도봉구 쌍문동
# 답변: 병원명은 한일병원 주소는 서울시 도봉구 우이천로 308(쌍문동)  전화번호는 02-901-3114 입니다.
#
# 질문: 서울 동대문구 용두동
# 답변: 병원명은 동대문구보건소 주소는 서울 동대문구 용두동 39-9  전화번호는 02-2127-4283 입니다.
#
# 질문: 서울 동대문구 휘경동
# 답변: 병원명은 삼육서울병원 주소는 서울 동대문구 망우로 82 전화번호는 1577-3675 입니다.
#
# 질문: 서울 동대문구 용두동
# 답변: 병원명은 서울특별시동부병원 주소는 서울 동대문구 무학로 124  전화번호는 920-9435 입니다.
#
# 질문: 서울 동대문구 청량리동
# 답변: 병원명은 서울성심병원 주소는 서울 동대문구 왕산로 259 전화번호는 966-1616 입니다.
#
# 질문: 서울 동대문구 회기동
# 답변: 병원명은 경희의료원 주소는 서울 동대문구 경희대로 23 전화번호는 958-8114 입니다.
#
# 질문: 서울 동작구 상도동
# 답변: 병원명은 동작구보건소 주소는 서울 동작구 상도2동 176-3 전화번호는 1533-5571 입니다.
#
# 질문: 서울 동작구 보라매동
# 답변: 병원명은 서울특별시 보라매병원 주소는 동작구 보라매로5길 20 전화번호는 02-870-2114 입니다.
#
# 질문: 서울 동작구 흑석동
# 답변: 병원명은 서울특별시 중앙대학교 병원 주소는 서울특별시 동작구 흑석로 102 전화번호는 1800-1114 입니다.
#
# 질문: 서울 마포구 성산동
# 답변: 병원명은 마포구보건소 주소는 서울 마포구 성산동 370 전화번호는 1577-3160 입니다.
#
# 질문: 서울 서대문구 연희동
# 답변: 병원명은 서대문구보건소 주소는 서울 서대문구 연희동  연희로242 (연희동 165-2) 전화번호는 02-330-1806 입니다.
#
# 질문: 서울 서대문구 신촌동
# 답변: 병원명은 세브란스병원 주소는 연세로 50-1 전화번호는 1599-1004 입니다.
#
# 질문: 서울 중구 신당동
# 답변: 병원명은 서울중구보건소 주소는 서울 중구 신당동 50-5 중구보건소   전화번호는 02-3396-8119 입니다.
#
# 질문: 서울 중구 저동
# 답변: 병원명은 인제대학교서울백병원 주소는 서울 중구 마른내로 9 백병원 전화번호는 02-2270-0114 입니다.
#
# 질문: 서울 중구 을지로
# 답변: 병원명은 국립중앙의료원 주소는 중구 을지로 245 전화번호는 02-2260-7114 입니다.
#
# 질문: 서울 서초구 서초동
# 답변: 병원명은 서초구보건소 주소는 서울 서초구 서초동(서초2동) 1376-3 서초구청 보건소 전화번호는 02-2155-8093 입니다.
#
# 질문: 서울 서초구 반포동
# 답변: 병원명은 가톨릭대학교 서울성모병원 주소는 서울시 서초구 반포대로 222 전화번호는 02-1588-1511 입니다.
#
# 질문: 서울 서초구 내곡동
# 답변: 병원명은 서울특별시 어린이병원 주소는 서울특별
#
# 질문: 서울 성동구 홍익동
# 답변: 병원명은 성동구보건소 주소는 서울 성동구 홍익동 (왕십리도선동) 16-15 성동구보건소  전화번호는 02-2286-7172 입니다.
#
# 질문: 서울 성동구 사근동
# 답변: 병원명은 한양대학교병원 주소는 서울특별시 성동구 왕십리로 222-1 (사근동) 전화번호는 02-2290-8114/8531 입니다.
#
# 질문: 서울 성동구 송정동
# 답변: 병원명은 성동군자의원 주소는 서울특별시 성동구 광나루로 323 송정빌딩 2층 전화번호는 02-499-7785 입니다.
#
# 질문: 서울 성북구 하월곡동
# 답변: 병원명은 성북구보건소 주소는 서울특별시 성북구 화랑로 63(하월곡동, 성북구보건소)  전화번호는 02-2241-5912 입니다.
#
# 질문: 서울 송파구 신천동
# 답변: 병원명은 송파구보건소 주소는 서울 송파구 신천동 29-5 송파구청, 보건소  전화번호는 02-2147-3478 입니다.
#
# 질문: 서울 송파구 풍납동
# 답변: 병원명은 서울아산병원 주소는 올림픽로43길 88 전화번호는 02-1688-7575 입니다.
#
# 질문: 서울 양천구 신정동
# 답변: 병원명은 양천구보건소 주소는 서울 양천구 신정동(신정6동) 321-5 양천보건소 전화번호는 1533-0407 입니다.
#
# 질문: 서울 양천구 신정동
# 답변: 병원명은 서울특별시 서남병원 주소는 양천구 신정이펜1로 20 전화번호는 1566-6688 입니다.
#
# 질문: 서울 양천구 목동
# 답변: 병원명은 홍익병원 주소는 서울 양천구 목동로 225  전화번호는 02-2693-5555 입니다.
#
# 질문: 서울 영등포구 당산동
# 답변: 병원명은 영등포구보건소 주소는 서울 영등포구 당산동3가(당산제1동) 385-1 영등포구청 영등포구보건소 전화번호는 02-2670-4954~9 입니다.
#
# 질문: 서울 영등포구 신길동
# 답변: 병원명은 한림대학교 강남성심병원 주소는 서울특별시 영등포구 신길로 1 전화번호는 1577-5587 입니다.
#
# 질문: 서울 영등포구 신길동
# 답변: 병원명은 의료법인 성애병원 주소는 서울특별시 영등포구 여의대방로 53길22 전화번호는 02-840-7538 입니다.
#
# 질문: 서울 영등포구 대림동
# 답변: 병원명은 명지성모병원 주소는 서울특별시 영등포구도림로 156 전화번호는 02-829-7800 입니다.
#
# 질문: 서울 영등포구 당산동
# 답변: 병원명은 인봉의료재단 영등포병원 주소는 서울특별시 영등포구 당산로31길 10 전화번호는 010-5334-7708 입니다.
#
# 질문: 서울 용산구 이태원동
# 답변: 병원명은 용산구보건소 주소는 서울 용산구 이태원동 34-87 전화번호는 02-2199-8373~6 입니다.
#
# 질문: 서울 용산구 한남동
# 답변: 병원명은 순천향대학교서울병원 주소는 용산구 대사관로 59(한남동) 전화번호는 02-709-9114 입니다.
#
# 질문: 서울 은평구 녹번동
# 답변: 병원명은 은평구보건소 주소는 서울 은평구 녹번동 84 은평구종합청사 은평구보건소 전화번호는 02-351-8640~1 입니다.
#
# 질문: 서울 은평구 역촌동
# 답변: 병원명은 서울특별시서북병원 주소는 은평구 갈현로7길 49 전화번호는 02-3156-3022 입니다.
#
# 질문: 서울 은평구 응암동
# 답변: 병원명은 서울특별시은평병원 주소는 은평구 백련산로 90 전화번호는 02-300-8124 입니다.
#
# 질문: 서울 은평구 갈현동
# 답변: 병원명은 의료법인 청구성심병원 주소는 서울 은평구 통일로 873 전화번호는 350-3300 입니다.
#
# 질문: 서울 종로구 청운효자동
# 답변: 병원명은 종로구보건소 주소는 서울 종로구 옥인동(청운효자동) 45-30 종로구보건소 전화번호는 02-2148-2060 입니다.
#
# 질문: 서울 종로구 평동
# 답변: 병원명은 강북삼성병원 주소는 서울시 종로구 새문안로 29 전화번호는 02-2001-1896 입니다.
#
# 질문: 서울 종로구 평동
# 답변: 병원명은 서울적십자병원 주소는 서울시 종로구 평동 164 전화번호는 02-2002-8000 입니다.
#
# 질문: 서울 중랑구 신내동
# 답변: 병원명은 중랑구보건소 주소는 서울 중랑구 신내2동 662 중랑구청  전화번호는 02-2094-0800 입니다.
#
# 질문: 서울 중랑구 신내동
# 답변: 병원명은 서울의료원 주소는 중랑구 신내로 156 전화번호는 02-2276-8333 입니다.
#
# 질문: 서울 중랑구 면목동
# 답변: 병원명은 녹색병원 주소는 중랑구 사가정로 49길 53 전화번호는 02-490-2000 입니다.
#
# 총  65 개의 대화가 존재합니다.

# %%
i = 1

# 출력, 입력 값 JSON 파일을 생성합니다.

prev = str(conversations[0].contentName) + str(conversations[0].contentType)

f = open(prev + '.json', 'w', encoding='UTF-8')

f.write('{ "id": "10d3155d-4468-4118-8f5d-15009af446d0", "name": "' + prev + '", "auto": true, "contexts": [], "responses": [ { "resetContexts": false, "affectedContexts": [], "parameters": [], "messages": [ { "type": 0, "lang": "ko", "speech": "' + conversations[0].answer + '" } ], "defaultResponsePlatforms": {}, "speech": [] } ], "priority": 500000, "webhookUsed": false, "webhookForSlotFilling": false, "fallbackIntent": false, "events": [] }')

f.close()

f = open(prev + '_usersays_ko.json', 'w', encoding='UTF-8')

f.write("[")

f.write('{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "' + conversations[0].question + '", "userDefined": false } ], "isTemplate": false, "count": 0 },')



while True:

    if i >= len(conversations):

        f.write("]")

        f.close()

        break;

    c = conversations[i]

    if prev == str(c.contentName) + str(c.contentType):

        f.write('{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "' + c.question + '", "userDefined": false } ], "isTemplate": false, "count": 0 },')

    else:

        f.write("]")

        f.close()

        # 출력, 입력 값 JSON 파일을 생성합니다.

        prev = str(c.contentName) + str(c.contentType)

        f = open(prev + '.json', 'w', encoding='UTF-8')

        f.write('{ "id": "10d3155d-4468-4118-8f5d-15009af446d0", "name": "' + prev + '", "auto": true, "contexts": [], "responses": [ { "resetContexts": false, "affectedContexts": [], "parameters": [], "messages": [ { "type": 0, "lang": "ko", "speech": "' + c.answer + '" } ], "defaultResponsePlatforms": {}, "speech": [] } ], "priority": 500000, "webhookUsed": false, "webhookForSlotFilling": false, "fallbackIntent": false, "events": [] }')

        f.close()

        f = open(prev + '_usersays_ko.json', 'w', encoding='UTF-8')

        f.write("[")

        f.write('{ "id": "3330d5a3-f38e-48fd-a3e6-000000000001", "data": [ { "text": "' + c.question + '", "userDefined": false } ], "isTemplate": false, "count": 0 },')

    i = i + 1
